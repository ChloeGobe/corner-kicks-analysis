# %% [markdown]
# # Corner Kick Analysis

# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt
from code.match_toolbox import Match
from code.corner_kicks_finder import CornerKickFinder

# %% [markdown]
# ## Analysing the match to find corner kick situations
#
# This section contains pieces of code to demonstrate how to use the functions implemented

# %%
# Studying the games where Liverpool and ManCity are facing each other
first_leg = Match(2440)
second_leg = Match(4039)

first_leg.gather_information()
second_leg.gather_information()

# %%
fig, ax = first_leg.plot_frame(2040)
plt.show()

# %%
second_leg.draw_gif_actions(2040)
# Out:
# 4039 : gif exists

# %%
# Finding the corner kicks
analyzer_first_leg = CornerKickFinder(match_id = 2440)
analyzer_first_leg.find_potentiel_corner_kicks()

analyzer_second_leg = CornerKickFinder(match_id = 4039)
analyzer_second_leg.find_potentiel_corner_kicks()
# Out:
# 2440 : Already found potentiel corner kicks - loading is over
# 4039 : Already found potentiel corner kicks - loading is over

# %%
analyzer_first_leg.df_potential
# Out:
#        frame      time
# 20687  20687  32:57.60
# 21441  21441  34:13.00
# 21617  21617  34:30.60
# 51578  51578  65:53.00
# 55837  55837  72:58.90
# 67035  67035  91:38.70

# %% [markdown]
# ## Analyzing the corner kicks

# %% [markdown]
# ### Plotting the situations

# %%
ax1 = first_leg.plot_frame(21441)
ax2 = first_leg.plot_frame(67035)
ax3 = first_leg.plot_frame(55837)

# %% [markdown]
# Different analysis can be made. Due to a limited amount of time, I was not able to code a lot of analysis but here are some analysis with one example

# %% [markdown]
# ### Number of players

# %%
# A ManCity corner kick
home, away = first_leg.count_players_in_box(21620)
print(f"There are {home} defenders in the box")
print(f"There are {away} attackers in the box")
# Out:
# There are 7 defenders in the box
# There are 5 attackers in the box

# %%
fig, ax = first_leg.plot_frame(21620)
plt.show()

# %%
# A Liverpool corner kick
home, away = first_leg.count_players_in_box(55840)
print(f"There are {away} defenders in the box")
print(f"There are {home} attackers in the box")
# Out:
# There are 8 defenders in the box
# There are 4 attackers in the box

# %%
fig, ax = first_leg.plot_frame(55840)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Movements of players

# %%
# Liverpool corner kick
fig, ax = first_leg.plot_frame(55875,40)

# %%
# ManCity corner kick
fig, ax = first_leg.plot_frame(21700,80)
